# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"vgsales.csv") #encoding='iso-8859-1')
df.columns.str.lower().str.replace(' ', '_') 
df.columns = df.columns.str.lower().str.replace(' ', '_')  
df.head(10)
# Out:
#    rank                       name platform    year         genre publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    na_sales  eu_sales  jp_sales  other_sales  global_sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62
# 9     26.93      0.63      0.28         0.47         28.31

# %%
df.describe()
# Out:
#                rank          year      na_sales      eu_sales      jp_sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         other_sales  global_sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %%
print(df.shape)
# Out:
# (16598, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rank          16598 non-null  int64
#  1   name          16598 non-null  object
#  2   platform      16598 non-null  object
#  3   year          16327 non-null  float64
#  4   genre         16598 non-null  object
#  5   publisher     16540 non-null  object
#  6   na_sales      16598 non-null  float64
#  7   eu_sales      16598 non-null  float64
#  8   jp_sales      16598 non-null  float64
#  9   other_sales   16598 non-null  float64
#  10  global_sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.drop(columns=["rank"],axis=1,inplace=True) 
df.duplicated().any()
# Out:
# True

# %%
len(set(df["name"]))
# Out:
# 11493

# %%
df.isnull().sum()
# Out:
# name              0
# platform          0
# year            271
# genre             0
# publisher        58
# na_sales          0
# eu_sales          0
# jp_sales          0
# other_sales       0
# global_sales      0
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum()
# Out:
# name            0
# platform        0
# year            0
# genre           0
# publisher       0
# na_sales        0
# eu_sales        0
# jp_sales        0
# other_sales     0
# global_sales    0
# dtype: int64

# %%
df.year.value_counts().sort_values(ascending = False)
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1257
# 2007.0    1201
# 2011.0    1136
# 2006.0    1008
# 2005.0     936
# 2002.0     829
# 2003.0     775
# 2004.0     744
# 2012.0     655
# 2015.0     614
# 2014.0     580
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     342
# 1999.0     338
# 1997.0     289
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1989.0      17
# 1983.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: year, dtype: int64

# %%
pd.crosstab(df["platform"], df["genre"])
# Out:
# genre     Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# platform
# 2600          55          1         1     5         9       8       4
# 3DO            0          1         0     0         0       1       0
# 3DS          180         36        14    53        28      19      10
# DC             3         11        12     0         2       0       6
# DS           335        238        36   389        89     236      66
# GB             6          5         0     8        18      15       2
# GBA          162         36        23    86       139      39      64
# GC            98         20        42    35        73      12      60
# GEN            3          2         5     1         7       0       1
# GG             0          0         0     0         1       0       0
# N64           37          4        29    18        30      12      57
# NES           13          1         4     2        28      14       4
# NG             0          0        11     0         0       0       0
# PC           161         65         5    22        11      25      56
# PCFX           0          0         0     0         0       0       0
# PS           154         67       108    76        64      32     144
# PS2          345        196       146   218       101      18     212
# PS3          373         72        76   121        36       2      90
# PS4          122         19        17    15        11       1      17
# PSP          217        213        73   104        36      44      65
# PSV          141         85        16    24        10       3      11
# SAT            3         26        31    15         5       5       8
# SCD            0          0         0     2         1       0       1
# SNES          12          4        25    17        26      13       9
# TG16           0          1         0     0         0       0       0
# WS             0          0         0     0         0       0       0
# Wii          230         83        41   272        57      54      92
# WiiU          63          3         5    21        16       4       3
# X360         318         47        65   122        24       6     102
# XB           152         26        44    45        49       7     122
# XOne          68         12         7    15         4       0      19
#
# genre     Role-Playing  Shooter  Simulation  Sports  Strategy
# platform
# 2600                 0       22           1      10         0
# 3DO                  0        0           1       0         0
# 3DS                 85        6          28      25        15
# DC                   4        3           1      10         0
# DS                 196       42         280     146        78
# GB                  21        1           5       9         7
# GBA                 73       40          18      88        18
# GC                  25       48          12     106        11
# GEN                  3        1           0       3         1
# GG                   0        0           0       0         0
# N64                  7       24          10      79         9
# NES                 11        7           0      14         0
# NG                   0        0           0       1         0
# PC                 103      145         112      49       184
# PCFX                 1        0           0       0         0
# PS                  97       96          60     221        70
# PS2                183      158          89     391        70
# PS3                117      155          30     210        22
# PS4                 47       34           5      43         5
# PSP                191       37          29     130        58
# PSV                 82        5           3      23         7
# SAT                 17       22           7      16        18
# SCD                  1        0           0       0         1
# SNES                50       10           9      49        15
# TG16                 0        1           0       0         0
# WS                   4        0           0       0         2
# Wii                 35       61          84     256        25
# WiiU                 6       10           1       8         3
# X360                75      197          36     215        27
# XB                  23      124          24     166        21
# XOne                13       33           3      36         3

# %%
plt.figure(figsize=(15, 10))
grafico1 = sns.countplot(x='platform',data=df, order = df['platform'].value_counts().index)
grafico1.set_title('Gráfico 1: Total de games ranqueados por plataforma',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gráfico 1: Total de games ranqueados por plataforma')

# %%
manufac = {'DS':'Nintendo', 'PS2':'Playstation', 'PS3':'Playstation','Wii':'Nintendo','X360':'Microsoft XBOX','PSP':'Playstation','PS':'Playstation',
          'PC':'PC','XB':'Microsoft XBOX', 'GBA':'Nintendo','GC':'Nintendo','3DS':'Nintendo','PSV':'Playstation','PS4':'Playstation','N64':'Nintendo',
          'SNES':'Nintendo','XOne':'Microsoft XBOX','SAT':'Others','WiiU':'Nintendo','2600':'Others','NES':'Nintendo','GB':'Nintendo','DC':'Others','GEN':'Others',
          'NG':'Others','SCD':'Others','WS':'Others','3DO':'Others','TG16':'Others','GG':'Others','PCFX':'Others'}
df['manufacturer'] = df["platform"].replace(manufac)
df
# Out:
#                                                    name platform    year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               genre   publisher  na_sales  eu_sales  jp_sales  other_sales  \
# 0            Sports    Nintendo     41.49     29.02      3.77         8.46
# 1          Platform    Nintendo     29.08      3.58      6.81         0.77
# 2            Racing    Nintendo     15.85     12.88      3.79         3.31
# 3            Sports    Nintendo     15.75     11.01      3.28         2.96
# 4      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16593      Platform       Kemco      0.01      0.00      0.00         0.00
# 16594       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16595        Racing  Activision      0.00      0.00      0.00         0.00
# 16596        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16597      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        global_sales manufacturer
# 0             82.74     Nintendo
# 1             40.24     Nintendo
# 2             35.82     Nintendo
# 3             33.00     Nintendo
# 4             31.37     Nintendo
# ...             ...          ...
# 16593          0.01     Nintendo
# 16594          0.01     Nintendo
# 16595          0.01  Playstation
# 16596          0.01     Nintendo
# 16597          0.01     Nintendo
#
# [16291 rows x 11 columns]

# %%
plt.figure(figsize=(15, 10))
grafico2 = sns.countplot(x ='manufacturer',data = df, order = df['manufacturer'].value_counts().index)
grafico2.set_title('Gráfico 2: Total de jogos por fabricantes',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gráfico 2: Total de jogos por fabricantes')

# %%
categorias = ['year','genre','global_sales','manufacturer']
df[categorias].head(20)
# Out:
#       year         genre  global_sales    manufacturer
# 0   2006.0        Sports         82.74        Nintendo
# 1   1985.0      Platform         40.24        Nintendo
# 2   2008.0        Racing         35.82        Nintendo
# 3   2009.0        Sports         33.00        Nintendo
# 4   1996.0  Role-Playing         31.37        Nintendo
# 5   1989.0        Puzzle         30.26        Nintendo
# 6   2006.0      Platform         30.01        Nintendo
# 7   2006.0          Misc         29.02        Nintendo
# 8   2009.0      Platform         28.62        Nintendo
# 9   1984.0       Shooter         28.31        Nintendo
# 10  2005.0    Simulation         24.76        Nintendo
# 11  2005.0        Racing         23.42        Nintendo
# 12  1999.0  Role-Playing         23.10        Nintendo
# 13  2007.0        Sports         22.72        Nintendo
# 14  2009.0        Sports         22.00        Nintendo
# 15  2010.0          Misc         21.82  Microsoft XBOX
# 16  2013.0        Action         21.40     Playstation
# 17  2004.0        Action         20.81     Playstation
# 18  1990.0      Platform         20.61        Nintendo
# 19  2005.0          Misc         20.22        Nintendo

# %%
print(df.groupby("publisher").size().idxmax())
print(df.groupby("publisher").size().max())
# Out:
# Electronic Arts
# 1339

# %%
print(df.groupby("genre").size().idxmax())
print(df.groupby("genre").size().max())
# Out:
# Action
# 3251

# %%
print(df.groupby("name").size().idxmax())
print(df.groupby("name").size().max())
# Out:
# Need for Speed: Most Wanted
# 12

# %%
plt.figure(figsize=(15, 5))
grafico3=sns.countplot(x='genre',data=df, order = df['genre'].value_counts().index)
grafico3.set_title('Gráfico 3: Gênero mais escolhidos entre os players',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gráfico 3: Gênero mais escolhidos entre os players')

# %%
plt.figure(figsize=(15, 5))
maior2010 = df[df.year >= 2010.]
grafico4 = sns.countplot(x=maior2010.year, data=df, hue='manufacturer')
grafico4.set_title('Grafico 4: Fabricantes mais utilizadas nos últimos 10 anos',fontsize=20)
plt.legend(loc='upper right',title='manufacturer')

# %%
grafico5 = df.groupby("year")["na_sales"].sum().plot(kind="line", grid=True, legend=True, figsize=(15, 5))
df.groupby("year")["eu_sales"].sum().plot(kind="line", grid=True, legend=True)
df.groupby("year")["jp_sales"].sum().plot(kind="line", grid=True, legend=True)
df.groupby("year")["other_sales"].sum().plot(kind="line", grid=True, legend=True)
grafico5.set_title('Grafico 5: Linha do tempo dos fabricantes',fontsize=15)
# Out:
# Text(0.5, 1.0, 'Grafico 5: Linha do tempo dos fabricantes')

# %%
sns.lmplot(x="global_sales", y="na_sales", data=df, fit_reg=True)
sns.lmplot(x="global_sales", y="eu_sales", data=df, fit_reg=True)
sns.lmplot(x="global_sales", y="jp_sales", data=df, fit_reg=True)
sns.lmplot(x="global_sales", y="other_sales", data=df, fit_reg=True)
